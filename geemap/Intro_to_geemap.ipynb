# %% [markdown]
# # **Intro to geemap**
# <img src="https://geemap.org/assets/logo.png" width="20%">

# %% [markdown]
# ## **Installing the Updated Version of geemap**
# Install geemap version `0.29.3` or a later release to enable the automatic authentication feature, as this functionality is only supported in these versions. To install other Python packages, you can use the `pip install package_name` command. To update a package, you can use `pip install --upgrade package_name` or `pip install -U package_name`.

# %%
# %pip install -U geemap
# Out:
# Requirement already satisfied: geemap in c:\users\krish\anaconda3\lib\site-packages (0.29.5)
# Collecting geemap
#   Obtaining dependency information for geemap from https://files.pythonhosted.org/packages/cd/f2/df8358d613cd666ececd4631f023512a272217d0e8b55f49884f31a9c37c/geemap-0.30.0-py2.py3-none-any.whl.metadata
#   Downloading geemap-0.30.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: bqplot in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (0.12.36)
# Requirement already satisfied: colour in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=0.1.347 in c:\users\krish\anaconda3\lib\site-packages (from geemap) (0.1.367)
# Requirement already satisfied: eerepr>=0.0.4 in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (0.0.4)
# Requirement already satisfied: folium>=0.13.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (0.14.0)
# Requirement already satisfied: geocoder in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (2.0.1)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.17.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (0.17.2)
# Requirement already satisfied: ipytree in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (3.7.0)
# Requirement already satisfied: numpy in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (1.24.2)
# Requirement already satisfied: pandas in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (1.5.3)
# Requirement already satisfied: plotly in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (5.13.0)
# Requirement already satisfied: pyperclip in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (1.8.2)
# Requirement already satisfied: pyshp>=2.1.3 in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (7.0.1)
# Requirement already satisfied: scooby in c:\users\krish\appdata\roaming\python\python311\site-packages (from geemap) (0.7.1)
# Requirement already satisfied: google-cloud-storage in c:\users\krish\appdata\roaming\python\python311\site-packages (from earthengine-api>=0.1.347->geemap) (2.7.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from earthengine-api>=0.1.347->geemap) (2.79.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from earthengine-api>=0.1.347->geemap) (2.16.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\krish\appdata\roaming\python\python311\site-packages (from earthengine-api>=0.1.347->geemap) (0.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\krish\appdata\roaming\python\python311\site-packages (from earthengine-api>=0.1.347->geemap) (0.21.0)
# Requirement already satisfied: requests in c:\users\krish\appdata\roaming\python\python311\site-packages (from earthengine-api>=0.1.347->geemap) (2.28.2)
# Requirement already satisfied: branca>=0.6.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from folium>=0.13.0->geemap) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\krish\appdata\roaming\python\python311\site-packages (from folium>=0.13.0->geemap) (3.1.2)
# Requirement already satisfied: ipywidgets in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipyfilechooser>=0.6.0->geemap) (7.7.3)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Requirement already satisfied: xyzservices>=2021.8.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipyleaflet>=0.17.0->geemap) (2023.2.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from bqplot->geemap) (5.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from pandas->geemap) (2022.7.1)
# Requirement already satisfied: click in c:\users\krish\appdata\roaming\python\python311\site-packages (from geocoder->geemap) (8.1.3)
# Requirement already satisfied: future in c:\users\krish\appdata\roaming\python\python311\site-packages (from geocoder->geemap) (0.18.3)
# Requirement already satisfied: ratelim in c:\users\krish\appdata\roaming\python\python311\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\krish\appdata\roaming\python\python311\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from matplotlib->geemap) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\krish\appdata\roaming\python\python311\site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from matplotlib->geemap) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from matplotlib->geemap) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from matplotlib->geemap) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from matplotlib->geemap) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from plotly->geemap) (8.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\krish\appdata\roaming\python\python311\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\krish\appdata\roaming\python\python311\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (4.9)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.21.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.6.2)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.10.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from jinja2>=2.9->folium>=0.13.0->geemap) (2.1.2)
# Requirement already satisfied: colorama in c:\users\krish\appdata\roaming\python\python311\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in c:\users\krish\appdata\roaming\python\python311\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\krish\appdata\roaming\python\python311\site-packages (from requests->earthengine-api>=0.1.347->geemap) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krish\appdata\roaming\python\python311\site-packages (from requests->earthengine-api>=0.1.347->geemap) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from requests->earthengine-api>=0.1.347->geemap) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krish\appdata\roaming\python\python311\site-packages (from requests->earthengine-api>=0.1.347->geemap) (2022.12.7)
# Requirement already satisfied: decorator in c:\users\krish\appdata\roaming\python\python311\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\krish\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (1.58.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\krish\appdata\roaming\python\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (4.22.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.347->geemap) (1.5.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.0.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.6)
# Requirement already satisfied: psutil in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.4)
# Requirement already satisfied: pyzmq>=20 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (25.0.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.2)
# Requirement already satisfied: backcall in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.37)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\krish\appdata\roaming\python\python311\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\krish\appdata\roaming\python\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (0.4.8)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.5.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\krish\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (305)
# Requirement already satisfied: argon2-cffi in c:\users\krish\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (21.3.0)
# Requirement already satisfied: nbformat in c:\users\krish\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.7.3)
# Requirement already satisfied: nbconvert>=5 in c:\users\krish\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.2.9)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\krish\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\krish\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.16.0)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\krish\appdata\roaming\python\python311\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.5.2)
# Requirement already satisfied: wcwidth in c:\users\krish\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\krish\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\krish\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.11.2)
# Requirement already satisfied: bleach in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.0.0)
# Requirement already satisfied: defusedxml in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\krish\appdata\roaming\python\python311\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\krish\appdata\roaming\python\python311\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (21.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.6.2)
# Requirement already satisfied: websocket-client in c:\users\krish\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\krish\appdata\roaming\python\python311\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.4)
# Requirement already satisfied: webencodings in c:\users\krish\appdata\roaming\python\python311\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\krish\appdata\roaming\python\python311\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.21)
# Downloading geemap-0.30.0-py2.py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.2 MB 991.0 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/2.2 MB 2.2 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.2 MB 3.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.9/2.2 MB 5.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.2 MB 5.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.2 MB 4.9 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 4.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 4.7 MB/s eta 0:00:01
#    -------------------------- ------------- 1.4/2.2 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.2 MB 4.2 MB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.2 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.2 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 4.0 MB/s eta 0:00:00
# Installing collected packages: geemap
#   Attempting uninstall: geemap
#     Found existing installation: geemap 0.29.5
#     Uninstalling geemap-0.29.5:
#       Successfully uninstalled geemap-0.29.5
# Successfully installed geemap-0.30.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## **Import the Required Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ee
import geemap

# %% [markdown]
# ## **Initialize a Map**

# %%
Map = geemap.Map()
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…
